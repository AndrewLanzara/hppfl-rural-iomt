# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchinfo import summary

# %%
import sys
import os

# Get the current working directory
current_dir = os.getcwd()

# Get the parent directory (which contains 'src')
parent_dir = os.path.dirname(current_dir)

# Add the parent directory to sys.path
sys.path.append(parent_dir)

from src.data_processing import complete_dataload

# %%
pretrain_loader, fl_loader  = complete_dataload()
# Out:
# Step 1: Loading raw SisFall data into memory...
# Step 2: Processing clients...
# Step 3: Finalizing Pre-train set (5 clients)...
#
# === READY ===
# Pre-train Set: 4500 windows
# FL Clients: 19 active clients

# %%
class Simple1DCNN(nn.Module):
    def __init__(self, num_classes= 2, input_channels=3):
        super(Simple1DCNN, self).__init__()
        
        # Feature Extraction ---
        # We group these layers to keep the 'forward' method clean.
        self.features = nn.Sequential(
            # Conv Layer 1: Takes raw signal, outputs 32 filtered versions
            nn.Conv1d(in_channels=input_channels, out_channels=32, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2),
            
            # Conv Layer 2: Learns more complex patterns from the 32 filters
            nn.Conv1d(in_channels=32, out_channels=32, kernel_size=3),
            nn.ReLU(),
            
            # Global Average Pooling:
            # Squeezes the time dimension down to 1 value per filter.
            # This handles variable length inputs gracefully.
            nn.AdaptiveAvgPool1d(1) 
        )
        
        # --- Classification ---
        self.classifier = nn.Sequential(
            nn.Linear(32, 32),
            nn.ReLU(),
            # Output layer
            nn.Linear(32, num_classes)
        )

    def forward(self, x):
        # x shape starts as: [Batch_Size, Channels, Time_Steps]
        
        # Pass through the convolutional layers
        x = self.features(x)
        
        # Flatten: remove the last dimension (Time_Steps) because it's now size 1
        x = x.view(x.size(0), -1)
        
        # Pass through the dense layers
        x = self.classifier(x)
        
        return x

# %%
model = Simple1DCNN()
print(summary(model, ))
# Out:
# ...
# Layer (type:depth-idx)                   Param #
# ...
# Simple1DCNN                              --
# ├─Sequential: 1-1                        --
# │    └─Conv1d: 2-1                       320
# │    └─ReLU: 2-2                         --
# │    └─MaxPool1d: 2-3                    --
# │    └─Conv1d: 2-4                       3,104
# │    └─ReLU: 2-5                         --
# │    └─AdaptiveAvgPool1d: 2-6            --
# ├─Sequential: 1-2                        --
# │    └─Linear: 2-7                       1,056
# │    └─ReLU: 2-8                         --
# │    └─Linear: 2-9                       66
# ...
# Total params: 4,546
# Trainable params: 4,546
# Non-trainable params: 0
# ...

# %%
def train_model(model, dataloader, num_epochs=10):
    """
    Trains the 1DCNN model.
    """

    # Define the Loss Function
    # CrossEntropyLoss is standard for classification
    criterion = nn.CrossEntropyLoss()
    
    # Define the Optimizer
    # Note: For DP with will be altered
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    # --- THE TRAINING LOOP ---
    for epoch in range(num_epochs):
        model.train() # Put model in 'training mode' (enables Dropout, etc.)
        running_loss = 0.0
        
        # Iterate over batches in the dataloader
        for batch_idx, (inputs, labels) in enumerate(dataloader):
            
            # 1. Zero the gradients
            # (PyTorch accumulates gradients by default; we must reset them)
            optimizer.zero_grad()
            
            # 2. Forward Pass
            # Push data through the model to get predictions
            outputs = model(inputs)
            
            # 3. Calculate Loss
            # Compare predictions (outputs) to actual truth (labels)
            loss = criterion(outputs, labels)
            
            # 4. Backward Pass (Backpropagation)
            # Calculate how much each weight contributed to the error
            loss.backward()
            
            # 5. Step
            # Update the weights based on the gradients
            optimizer.step()
            
            # Keep track of stats
            running_loss += loss.item()
            
        # Print stats at the end of every epoch
        avg_loss = running_loss / len(dataloader)
        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}")

    print("Training Complete!")
    return model

# %%
trained_model = train_model(model, pretrain_loader, num_epochs=5)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 trained_model = train_model(model, pretrain_loader, num_epochs=5)
#
# Cell In[6], line 32, in train_model(model, dataloader, num_epochs)
#      28 outputs = model(inputs)
#      30 # 3. Calculate Loss
#      31 # Compare predictions (outputs) to actual truth (labels)
# ---> 32 loss = criterion(outputs, labels)
#      34 # 4. Backward Pass (Backpropagation)
#      35 # Calculate how much each weight contributed to the error
#      36 loss.backward()
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# ...
